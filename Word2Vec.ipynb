# %%
from pyspark.ml.feature import HashingTF, IDF, Tokenizer, Word2Vec
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.ml.classification import LogisticRegression
import pyspark.sql.functions as F
import pyspark.sql.types as T

sc = SparkContext('local')
spark = SparkSession(sc)

# %%
df = spark.read.format("csv").option("inferschema","true").option("header", "true").option("delimiter", "\t").load("trainReviews.tsv")

# %%
tokenizer = Tokenizer(inputCol="text", outputCol="words")
wordsData = tokenizer.transform(df)
wordsData.show(5)
# Out:
# +----+--------+--------------------+--------------------+
# |  id|category|                text|               words|
# +----+--------+--------------------+--------------------+
# | 858|       0|burnt money is th...|[burnt, money, is...|
# |1762|       1|the   italian hit...|[the, , , italian...|
# | 235|       0|at times   you d ...|[at, times, , , y...|
# | 712|       0|after a marketing...|[after, a, market...|
# |1319|       1|john cusack is th...|[john, cusack, is...|
# +----+--------+--------------------+--------------------+
# only showing top 5 rows

# %%
word2Vec = Word2Vec(inputCol="words", outputCol="result")

# %%
model = word2Vec.fit(wordsData)

# %%
model.getVectors().show(100)
# Out:
# +-------------+--------------------+
# |         word|              vector|
# +-------------+--------------------+
# |     incident|[0.00438264850527...|
# |      serious|[0.03595425561070...|
# |        brink|[0.00153260945808...|
# |     sinister|[-0.0162860918790...|
# |       breaks|[-0.0075081149116...|
# |    forgotten|[-0.0226922817528...|
# |     precious|[-0.0177151039242...|
# |        mario|[-0.0197891276329...|
# |   compliment|[-0.0030940368305...|
# |        lover|[-0.0201899744570...|
# |     terrible|[-0.0321051441133...|
# |         lion|[0.00814848858863...|
# |         rate|[-0.0318052470684...|
# |   inevitable|[0.01720425672829...|
# |  nonetheless|[-0.0055500366725...|
# |       lights|[0.00479545490816...|
# |         rage|[0.01458693947643...|
# |        knack|[-8.9934479910880...|
# |         snow|[-0.0167874917387...|
# |     headache|[5.87414833717048...|
# |     laughing|[0.02785842493176...|
# |      michael|[-0.1444831639528...|
# |        looks|[-0.0676502808928...|
# |     zemeckis|[-0.0028793253004...|
# |      ranking|[0.00990131217986...|
# |         gory|[-0.0025827439967...|
# |   california|[0.00225326092913...|
# |        scare|[0.00445754267275...|
# |     magnolia|[0.00233831442892...|
# |   extraneous|[-0.0061261006630...|
# |       craven|[-0.0151041606441...|
# |     accident|[-0.0230195112526...|
# |    locations|[-0.0076109576039...|
# |      beneath|[0.00389035441912...|
# |   physically|[-0.0067674200981...|
# |conversations|[-0.0068514160811...|
# |     scenario|[7.23640783689916...|
# |       gamble|[-0.0049584517255...|
# |        ideas|[-0.0318605080246...|
# |      gilmore|[0.00842091627418...|
# |    uniformly|[-0.0071009336970...|
# |        sweet|[-0.0572466589510...|
# |         lush|[-0.0123916538432...|
# |        sword|[-0.0035425983369...|
# | particularly|[-0.0231056734919...|
# |         used|[0.04097494482994...|
# |          eye|[-0.0342554971575...|
# |     striking|[-0.0096596013754...|
# |      brosnan|[0.00490582734346...|
# |   futuristic|[0.00293288053944...|
# |        simon|[-0.0736394748091...|
# |     franklin|[-0.0273653455078...|
# |      allowed|[0.00219191377982...|
# |           98|[-0.0061481730081...|
# |    reference|[-5.2000308642163...|
# |    secretary|[-0.0208797249943...|
# | manipulative|[-0.0168539788573...|
# |        vivid|[0.00756632816046...|
# |     arquette|[-0.0764463171362...|
# |            e|[-0.0434992238879...|
# |        swarm|[-0.0078191105276...|
# |    slapstick|[-0.0145654873922...|
# |        abyss|[-0.0137742655351...|
# |       aliens|[-0.0174640994518...|
# |    beautiful|[-0.0637207776308...|
# |   babysitter|[0.01205248199403...|
# |    providing|[-0.0069109695032...|
# |       sunday|[-0.0086781345307...|
# |   altogether|[0.01062638591974...|
# |      writing|[-0.0164002943783...|
# |    believing|[-0.0069107436574...|
# |        sarah|[-0.0227344781160...|
# |        funny|[-0.0941501036286...|
# |       launch|[-0.0072756879962...|
# |        joker|[-0.0305647850036...|
# |     birthday|[-0.0249642375856...|
# |         emma|[-0.0323389694094...|
# |        blair|[-0.0246204733848...|
# |      fashion|[0.01210215128958...|
# |  devastating|[0.00329032843001...|
# |        fluff|[-7.2270986856892...|
# |   conviction|[-0.0082285637035...|
# |      explore|[0.00509814219549...|
# |         tune|[-0.0131642594933...|
# |       killed|[-0.0297549609094...|
# |      marquis|[-0.0232628416270...|
# |      species|[0.01386186480522...|
# |       walker|[0.00303213950246...|
# |     julianne|[-0.0161021072417...|
# |         down|[-0.0562616549432...|
# |        weird|[-0.0483482033014...|
# |       serial|[0.01814535818994...|
# |    slightest|[-0.0160950310528...|
# |     elements|[0.00396864069625...|
# |         wash|[-0.0023839438799...|
# |           ku|[-0.0017510125180...|
# |     existenz|[0.00471755117177...|
# |      masters|[-6.5516924951225...|
# |     portrays|[-0.0311648454517...|
# |     teenager|[0.00939476303756...|
# +-------------+--------------------+
# only showing top 100 rows

# %%
synonyms = model.findSynonyms('sinister', 100)

# %%
synonyms.show(100)
# Out:
# +------------+------------------+
# |        word|        similarity|
# +------------+------------------+
# |        pete|0.7448366284370422|
# |       ricky|0.7204491496086121|
# |  astounding|0.7153885364532471|
# |       bitch|0.7118590474128723|
# |   homicidal| 0.710591197013855|
# |        king|0.7058147192001343|
# |       score| 0.699134111404419|
# |        skin|0.6960994005203247|
# |      delmar|0.6951101422309875|
# |        gang|0.6895015239715576|
# |         car|0.6856046319007874|
# |        buck| 0.681916356086731|
# |    producer|0.6787402629852295|
# |      quirky|0.6778930425643921|
# |        neck|0.6763299703598022|
# |        kurt|0.6757290363311768|
# |      gentle|0.6725389361381531|
# |     madness|0.6722574234008789|
# |       terry| 0.670669436454773|
# |      jerome|0.6685158610343933|
# |      quotes|0.6677120923995972|
# |    birthday|0.6663986444473267|
# |     fighter| 0.665898323059082|
# |        bold|0.6608845591545105|
# |     kingpin|0.6598169207572937|
# |      malick| 0.658460259437561|
# |         cop|0.6577965617179871|
# |       death|0.6555906534194946|
# |       quick|0.6544247269630432|
# |     destiny|0.6536856293678284|
# |   selection|0.6533554792404175|
# |       girls|0.6525595784187317|
# |        hoke|0.6519344449043274|
# |     leaving|0.6504316926002502|
# |        hart|0.6488397121429443|
# |    daughter|0.6477364301681519|
# |       dutch|0.6472295522689819|
# |        thai|0.6463460326194763|
# |    costumes|0.6457614898681641|
# |     ulysses|0.6444573998451233|
# |  thereafter|0.6435471773147583|
# |      eldest|0.6429803967475891|
# |       homes|0.6424161791801453|
# |     tension|0.6404542922973633|
# |occasionally|0.6385934948921204|
# |    kennesaw|0.6383293271064758|
# | replacement|0.6368802189826965|
# |     current|0.6362122297286987|
# |    williams|0.6349329352378845|
# |        roth|0.6340099573135376|
# |          jo|0.6338805556297302|
# |          co|0.6330876350402832|
# |       kicks|0.6328915953636169|
# |        troi|0.6323308348655701|
# |       slick| 0.630989670753479|
# |    sergeant|0.6305424571037292|
# |     kenneth|0.6302847862243652|
# |     malcolm|0.6293041110038757|
# |      visits|0.6292312145233154|
# |       ethan|0.6289141774177551|
# |       alice|0.6283240914344788|
# |     british|0.6274943351745605|
# |     suicide|0.6272991895675659|
# |    ruthless|0.6267862319946289|
# |      clever|0.6260308027267456|
# |      mortal| 0.625544011592865|
# |        hara|0.6252496242523193|
# |     hackman|0.6251304745674133|
# |     hoggett| 0.625108003616333|
# |   execution|0.6245461106300354|
# |     awkward|0.6244283318519592|
# |      hopper|0.6240729093551636|
# |      father| 0.623375654220581|
# |      denise|0.6228572130203247|
# |      burton|0.6227953433990479|
# |      dumber|0.6227243542671204|
# |        joel|0.6220375299453735|
# |       hammy|0.6213749051094055|
# |   catherine|0.6206558346748352|
# |     murders|0.6201630234718323|
# |    arquette| 0.619758129119873|
# |       rocky|0.6185130476951599|
# |   alexander|0.6183065176010132|
# |      friend|0.6176554560661316|
# |       jerry|0.6176120638847351|
# |      tucker|0.6151686310768127|
# |     emperor|0.6149839758872986|
# |      daniel|0.6146777868270874|
# |      lonely|0.6146448850631714|
# |       platt|0.6140329241752625|
# |    wondrous|0.6139103770256042|
# |         ben|0.6138750314712524|
# |        wife|0.6137294769287109|
# |       danny|0.6125839948654175|
# |       scary| 0.612107515335083|
# |     objects|0.6115593314170837|
# |   depressed|0.6110981106758118|
# |        caan|0.6104837656021118|
# |        sean|0.6104739904403687|
# |     affleck| 0.610417366027832|
# +------------+------------------+
